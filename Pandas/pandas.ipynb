# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart-disease.csv")

# %% [markdown]
# # Reading first 5 rows of the table

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # Comparing number of those who have heart disease and those who don't

# %%
df.target.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Cars_Series = pd.Series(['BMW','TOYOTA','HONDA'])
Cars_Series
# Out:
# 0       BMW
# 1    TOYOTA
# 2     HONDA
# dtype: object

# %%
colors_Series = pd.Series(['Red','Green','Blue'])
colors_Series
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %% [markdown]
# ## This is examples of Series dataType in Pandas

# %%
car_data =pd.DataFrame({'Car Make':Cars_Series,'Color':colors_Series})
car_data
# Out:
#   Car Make  Color
# 0      BMW    Red
# 1   TOYOTA  Green
# 2    HONDA   Blue

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting DataFrame
car_sales.to_csv("exported.csv", index =False)

# %%
# Importing it again
car_sales_2= pd.read_csv("exported.csv")
car_sales_2
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attribute
car_sales.dtypes
# Function
# car_sales.to_csv("export.csv")
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.head(15)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### .loc & .iloc

# %%
animals = pd.Series(['cat','dog','bird','panda','snake'],
                   index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
# iloc
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales['Colour'])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
pd.crosstab(car_sales["Doors"],car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales.value_counts()
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# BMW     Black   11179          5      $22,000.00    1
# Honda   Blue    45698          4      $7,500.00     1
#                 54738          4      $7,000.00     1
#         Red     87899          4      $5,000.00     1
# Nissan  White   31600          4      $9,700.00     1
#                 213095         4      $3,500.00     1
# Toyota  Blue    32549          3      $7,000.00     1
#         Green   99213          4      $4,500.00     1
#         White   60000          4      $6,250.00     1
#                 150043         4      $4,000.00     1
# dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Make'].value_counts()
# Out:
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: Make, dtype: int64

# %% [markdown]
# ### Groupby

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# # !!! Use groupby to group for a certain values in the columns !!!

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','').astype(int)
# Out:
# <ipython-input-46-2f8a152b7777>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'] /=100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
csm = pd.read_csv("car-sales-missing-data.csv")
csm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
csm['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
csm['Odometer'].fillna(csm['Odometer'].mean(),inplace=True)

# %%
csm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
csm.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
csm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
csm.dropna(inplace=True)

# %%
csm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
csm = pd.read_csv('car-sales-missing-data.csv')

# %%
csm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
csm_d = csm

# %%
csm_d['Odometer'].fillna(csm['Odometer'].mean(),inplace = True)

# %%
csm_d.dropna(inplace = True)

# %%
csm_d
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
csm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
csm = pd.read_csv("car-sales-missing-data.csv")

# %%
csm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats_col = pd.Series([5,5,5,5,5])
car_sales['Seats'] = seats_col

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales['Seats'].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
car_sales['Fuel per 100KM']=[9.5,8.6,6.0,3.5,6.7,5.0,8.4,6.2,5.7,7.2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100*car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2
#
#    Total fuel used
# 0        14254.085
# 1         7559.314
# 2         1952.940
# 3          391.265
# 4        14277.365
# 5         4960.650
# 6         3838.632
# 7         3393.756
# ...

# %%
car_sales["Num of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2
#
#    Total fuel used  Num of Wheels
# 0        14254.085              4
# 1         7559.314              4
# 2         1952.940              4
# 3          391.265              4
# ...

# %%
car_sales['Total fuel used (L)'] = car_sales['Total fuel used']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2
#
#    Total fuel used  Num of Wheels  Total fuel used (L)
# 0        14254.085              4            14254.085
# 1         7559.314              4             7559.314
# ...

# %%
car_sales.drop("Total fuel used",axis=1,inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2
#
#    Num of Wheels  Total fuel used (L)
# 0              4            14254.085
# 1              4             7559.314
# 2              4             1952.940
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 9  nissan  White          31600      4   9700.0    5.0             7.2
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 8  toyota  White          60000      4   6250.0    5.0             5.7
#
#    Num of Wheels  Total fuel used (L)
# 3              4              391.265
# 7              4             3393.756
# 4              4            14277.365
# ...

# %%
car_sales_shuffled.reset_index(drop = True, inplace = True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     bmw  Black          11179      5  22000.0    5.0             3.5
# 1   honda   Blue          54738      4   7000.0    5.0             6.2
# 2  nissan  White         213095      4   3500.0    5.0             6.7
# 3  toyota  Green          99213      4   4500.0    5.0             5.0
# 4   honda   Blue          45698      4   7500.0    5.0             8.4
# 5  nissan  White          31600      4   9700.0    5.0             7.2
# 6   honda    Red          87899      4   5000.0    5.0             8.6
# 7  toyota   Blue          32549      3   7000.0    5.0             6.0
# 8  toyota  White         150043      4   4000.0    5.0             9.5
# 9  toyota  White          60000      4   6250.0    5.0             5.7
#
#    Num of Wheels  Total fuel used (L)
# 0              4              391.265
# 1              4             3393.756
# 2              4            14277.365
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             9.5
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             3.5
# 4  nissan  White         213095      4   3500.0    5.0             6.7
# 5  toyota  Green          99213      4   4500.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             8.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.2
# 8  toyota  White          60000      4   6250.0    5.0             5.7
# 9  nissan  White          31600      4   9700.0    5.0             7.2
#
#    Num of Wheels  Total fuel used (L)
# 0              4            14254.085
# 1              4             7559.314
# 2              4             1952.940
# ...

# %%
car_sales['Odometer (KM)'] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             9.5
# 1   honda    Red      54936.875      4   5000.0    5.0             8.6
# 2  toyota   Blue      20343.125      3   7000.0    5.0             6.0
# 3     bmw  Black       6986.875      5  22000.0    5.0             3.5
# 4  nissan  White     133184.375      4   3500.0    5.0             6.7
# 5  toyota  Green      62008.125      4   4500.0    5.0             5.0
# 6   honda   Blue      28561.250      4   7500.0    5.0             8.4
# 7   honda   Blue      34211.250      4   7000.0    5.0             6.2
# 8  toyota  White      37500.000      4   6250.0    5.0             5.7
# 9  nissan  White      19750.000      4   9700.0    5.0             7.2
#
#    Num of Wheels  Total fuel used (L)
# 0              4            14254.085
# 1              4             7559.314
# 2              4             1952.940
# ...

# %%
car_sales.rename(columns={"Odometer (KM)":"Odometer (M)"},inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (M)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White     93776.875      4   4000.0    5.0             9.5
# 1   honda    Red     54936.875      4   5000.0    5.0             8.6
# 2  toyota   Blue     20343.125      3   7000.0    5.0             6.0
# 3     bmw  Black      6986.875      5  22000.0    5.0             3.5
# 4  nissan  White    133184.375      4   3500.0    5.0             6.7
# 5  toyota  Green     62008.125      4   4500.0    5.0             5.0
# 6   honda   Blue     28561.250      4   7500.0    5.0             8.4
# 7   honda   Blue     34211.250      4   7000.0    5.0             6.2
# 8  toyota  White     37500.000      4   6250.0    5.0             5.7
# 9  nissan  White     19750.000      4   9700.0    5.0             7.2
#
#    Num of Wheels  Total fuel used (L)
# 0              4            14254.085
# 1              4             7559.314
# 2              4             1952.940
# 3              4              391.265
# ...

# %%
dates= pd.date_range('20130101',periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df2 = pd.DataFrame(
{
    "A":1.0,
    "B":pd.Timestamp("20130102"),
    "C":pd.Series(1,index=list(range(4)), dtype="float32"),
    "D":np.array([3]*4,dtype="int32"),
    "E":pd.Categorical(["test","train","test","train"]),
    "F":"foo",
}
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df.to_numpy()
# Out:
# array([[ 0.02745062,  0.47615027, -1.00548006,  0.35767858],
#        [ 0.46228413, -1.31589244, -1.2982594 , -0.4854828 ],
#        [-1.1129627 ,  0.32708093, -0.25049196, -0.6345957 ],
#        [ 0.6970253 ,  2.0861462 , -0.09043665,  1.27710034],
#        [-0.30739663, -0.79138391, -1.23885875, -0.53431621],
#        [ 0.1856799 ,  1.93173776,  1.57358323,  0.60269378]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.007987  0.452306 -0.384991  0.097180
# std    0.643052  1.381861  1.085267  0.773226
# min   -1.112963 -1.315892 -1.298259 -0.634596
# 25%   -0.223685 -0.511768 -1.180514 -0.522108
# 50%    0.106565  0.401616 -0.627986 -0.063902
# 75%    0.393133  1.567841 -0.130450  0.541440
# max    0.697025  2.086146  1.573583  1.277100

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.027451    0.462284   -1.112963    0.697025   -0.307397    0.185680
# B    0.476150   -1.315892    0.327081    2.086146   -0.791384    1.931738
# C   -1.005480   -1.298259   -0.250492   -0.090437   -1.238859    1.573583
# D    0.357679   -0.485483   -0.634596    1.277100   -0.534316    0.602694

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.357679 -1.005480  0.476150  0.027451
# 2013-01-02 -0.485483 -1.298259 -1.315892  0.462284
# 2013-01-03 -0.634596 -0.250492  0.327081 -1.112963
# 2013-01-04  1.277100 -0.090437  2.086146  0.697025
# 2013-01-05 -0.534316 -1.238859 -0.791384 -0.307397
# 2013-01-06  0.602694  1.573583  1.931738  0.185680

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-06  0.185680  1.931738  1.573583  0.602694
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01  0.027451  0.476150
# 2013-01-02  0.462284 -1.315892
# 2013-01-03 -1.112963  0.327081
# 2013-01-04  0.697025  2.086146
# 2013-01-05 -0.307397 -0.791384
# 2013-01-06  0.185680  1.931738

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.027451  0.476150       NaN  0.357679
# 2013-01-02  0.462284       NaN       NaN       NaN
# 2013-01-03       NaN  0.327081       NaN       NaN
# 2013-01-04  0.697025  2.086146       NaN  1.277100
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06  0.185680  1.931738  1.573583  0.602694

# %%
df2 =df.copy()

# %%
df2["E"]=["one","one","two","three","four","three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.027451  0.476150 -1.005480  0.357679    one
# 2013-01-02  0.462284 -1.315892 -1.298259 -0.485483    one
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596    two
# 2013-01-04  0.697025  2.086146 -0.090437  1.277100  three
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316   four
# 2013-01-06  0.185680  1.931738  1.573583  0.602694  three

# %%
df2[df2["E"].isin(["two","four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.112963  0.327081 -0.250492 -0.634596   two
# 2013-01-05 -0.307397 -0.791384 -1.238859 -0.534316  four

# %%
s1 = pd.date_range("20000813",periods=6)

# %%
s1
# Out:
# DatetimeIndex(['2000-08-13', '2000-08-14', '2000-08-15', '2000-08-16',
#                '2000-08-17', '2000-08-18'],
#               dtype='datetime64[ns]', freq='D')

# %%
len(df)
# Out:
# 6

# %%
len(car_sales)
# Out:
# 10

# %%
df.loc[:,"D"]=[5]*len(df)

# %%
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.027451  0.476150 -1.005480  5
# 2013-01-02  0.462284 -1.315892 -1.298259  5
# 2013-01-03 -1.112963  0.327081 -0.250492  5
# 2013-01-04  0.697025  2.086146 -0.090437  5
# 2013-01-05 -0.307397 -0.791384 -1.238859  5
# 2013-01-06  0.185680  1.931738  1.573583  5

# %%
df.mean()
# Out:
# A   -0.007987
# B    0.452306
# C   -0.384991
# D    5.000000
# dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index= dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.027451  0.476150 -1.005480  5
# 2013-01-02  0.462284 -1.315892 -1.298259  5
# 2013-01-03 -1.112963  0.327081 -0.250492  5
# 2013-01-04  0.697025  2.086146 -0.090437  5
# 2013-01-05 -0.307397 -0.791384 -1.238859  5
# 2013-01-06  0.185680  1.931738  1.573583  5

# %%
df.sub(s,axis="index")
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -2.112963 -0.672919 -1.250492  4.0
# 2013-01-04 -2.302975 -0.913854 -3.090437  2.0
# 2013-01-05 -5.307397 -5.791384 -6.238859  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.027451  0.476150 -1.005480   5
# 2013-01-02  0.489735 -0.839742 -2.303739  10
# 2013-01-03 -0.623228 -0.512661 -2.554231  15
# 2013-01-04  0.073797  1.573485 -2.644668  20
# 2013-01-05 -0.233599  0.782101 -3.883527  25
# 2013-01-06 -0.047919  2.713839 -2.309944  30

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A    1.809988
# B    3.402039
# C    2.871843
# D    0.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    5
# 1    0
# 2    2
# 3    0
# 4    0
# 5    6
# 6    1
# 7    5
# 8    4
# 9    2
# dtype: int32

# %%
s.value_counts()
# Out:
# 0    3
# 2    2
# 5    2
# 1    1
# 4    1
# 6    1
# dtype: int64

# %%
s.hist()
# Out:
# <AxesSubplot:>

# %%
s =pd.Series(["A","B","C","Aaba","Baca",np.nan,"CABA","dog","cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ### Merge

# %% [markdown]
# ##### Concat

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  0.445800  0.152155  0.170791  1.224831
# 1 -0.606996  0.417372  0.570432 -0.680540
# 2 -0.126658 -1.564015 -0.250103 -2.421820
# 3 -0.099629  1.189284  0.390116 -1.067293
# 4 -1.129741  0.167468 -0.646184 -0.441317
# 5 -0.167833  1.188979 -0.419250 -0.655149
# 6 -0.104165 -0.531701 -0.769980  0.059952
# 7 -0.711909 -0.071355 -0.124926 -1.370503
# 8  0.559313  0.345218 -0.136501  1.044509
# 9  0.714043 -0.183253 -0.469903 -0.008518

# %%
pieces = [df[:3],df[3:7],df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.445800  0.152155  0.170791  1.224831
# 1 -0.606996  0.417372  0.570432 -0.680540
# 2 -0.126658 -1.564015 -0.250103 -2.421820
# 3 -0.099629  1.189284  0.390116 -1.067293
# 4 -1.129741  0.167468 -0.646184 -0.441317
# 5 -0.167833  1.188979 -0.419250 -0.655149
# 6 -0.104165 -0.531701 -0.769980  0.059952
# 7 -0.711909 -0.071355 -0.124926 -1.370503
# 8  0.559313  0.345218 -0.136501  1.044509
# 9  0.714043 -0.183253 -0.469903 -0.008518

# %% [markdown]
# ##### Join

# %%
left = pd.DataFrame({"key":["foo","foo"], "lval":[1,2]})
right = pd.DataFrame({"key":["foo","foo"], "rval":[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.concat([left,right])
# Out:
#    key  lval  rval
# 0  foo   1.0   NaN
# 1  foo   2.0   NaN
# 0  foo   NaN   4.0
# 1  foo   NaN   5.0

# %%
pd.merge(left,right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left=pd.DataFrame({"key":["foo","foo","foo","foo"],"lval":[1,2,3,4]})
right = pd.DataFrame({"key":["foo","bar","bar","bar"],"rval":[5,6,7,8]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2
# 2  foo     3
# 3  foo     4

# %%
right
# Out:
#    key  rval
# 0  foo     5
# 1  bar     6
# 2  bar     7
# 3  bar     8

# %%
pd.merge(left,right,on = "key")
# Out:
#    key  lval  rval
# 0  foo     1     5
# 1  foo     2     5
# 2  foo     3     5
# 3  foo     4     5

# %%
left = pd.DataFrame({'key':["foo","bar"],'lval':[1,2]})
right = pd.DataFrame({'key':["foo","bar"],'rval':[4,5]})

# %%
pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# #### Grouping

# %%
df = pd.DataFrame(
    {'A':["foo","bar","foo","bar","foo","bar","foo","foo"],
     "B":["one","one","two","three","two","two","one","three"],
     "C":np.random.randn(8),
     "D":np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -1.520309  2.034569
# 1  bar    one -0.600373  0.450442
# 2  foo    two -0.713450  0.875813
# 3  bar  three  1.084077 -0.457585
# 4  foo    two  0.612970 -0.539049
# 5  bar    two  0.207946 -0.432636
# 6  foo    one  2.505139 -0.333640
# 7  foo  three -1.657724 -0.831307

# %%
df.groupby("A").sum()
# Out:
#             C         D
# A
# bar  0.691649 -0.439779
# foo -0.773374  1.206385

# %%
df.groupby(["A","B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.600373  0.450442
#     three  1.084077 -0.457585
#     two    0.207946 -0.432636
# foo one    0.984830  1.700929
#     three -1.657724 -0.831307
#     two   -0.100480  0.336763

# %% [markdown]
# ### Stack

# %%
a =("John", "Charles", "Mike")
b =("Jenny", "Christy", "Monica")

x = zip(a,b)

# %%
[i for i in x]
# Out:
# [('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica')]

# %%
tuples = list(
zip(

    ["bar","bar","baz","baz","foo","foo","qux","qux"],
    ["one","two","one","two","one","two","one","two"],
)
)

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8,2),index = index,columns=["A","B"])

# %%
df
# Out:
#                      A         B
# first second
# bar   one    -1.255872 -0.540163
#       two    -0.676679 -0.118722
# baz   one    -0.507511  0.274582
#       two     0.378393  0.387299
# foo   one    -1.105462  1.016107
#       two     1.630127 -0.546523
# qux   one     0.078682  1.519010
#       two     1.189634 -0.668483

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -1.255872 -0.540163
#       two    -0.676679 -0.118722
# baz   one    -0.507511  0.274582
#       two     0.378393  0.387299

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -1.255872
#                B   -0.540163
#        two     A   -0.676679
#                B   -0.118722
# baz    one     A   -0.507511
#                B    0.274582
#        two     A    0.378393
#                B    0.387299
# dtype: float64

# %%
stacked.unstack()
# Out:
# first          bar       baz
#   second
# A one    -1.255872 -0.507511
#   two    -0.676679  0.378393
# B one    -0.540163  0.274582
#   two    -0.118722  0.387299

# %% [markdown]
# ### Pivot tables

# %%
df = pd.DataFrame(
{
    "A":["one","one","two","three"]*3,
    "B":["A","B","C"]*4,
    "C":["foo","foo","foo","bar","bar","bar"]*2,
    "D":np.random.randn(12),
    "E":np.random.rand(12),
})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.505288  0.123445
# 1     one  B  foo -0.648348  0.233118
# 2     two  C  foo -0.119096  0.090017
# 3   three  A  bar -0.726182  0.406357
# 4     one  B  bar -2.074471  0.878129
# 5     one  C  bar -0.690557  0.676798
# 6     two  A  foo  0.522204  0.726003
# 7   three  B  foo  2.116999  0.350730
# 8     one  C  foo -0.174892  0.016790
# 9     one  A  bar -0.162216  0.561205
# 10    two  B  bar -0.668224  0.440721
# 11  three  C  bar -0.197746  0.647167

# %%
pd.pivot_table(df,values ="D",index=["A",'B'],columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.162216 -1.505288
#       B -2.074471 -0.648348
#       C -0.690557 -0.174892
# three A -0.726182       NaN
#       B       NaN  2.116999
#       C -0.197746       NaN
# two   A       NaN  0.522204
#       B -0.668224       NaN
#       C       NaN -0.119096

# %% [markdown]
# ## Time series

# %%
rng = pd.date_range('1/1/2012', periods= 100, freq="S")
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
# ...

# %%
ts= pd.Series(np.random.randint(0,500, len(rng)), index= rng)
ts
# Out:
# 2012-01-01 00:00:00    220
# 2012-01-01 00:00:01    166
# 2012-01-01 00:00:02    150
# 2012-01-01 00:00:03     87
# 2012-01-01 00:00:04    256
#                       ...
# 2012-01-01 00:01:35    226
# 2012-01-01 00:01:36     36
# 2012-01-01 00:01:37    153
# 2012-01-01 00:01:38    366
# 2012-01-01 00:01:39    142
# Freq: S, Length: 100, dtype: int32

# %%
ts.resample("5min").sum()
# Out:
# 2012-01-01    24568
# Freq: 5T, dtype: int32

# %%
rng= pd.date_range("3/6/2012 00:00",periods= 5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.162303
# 2012-03-07   -1.398904
# 2012-03-08   -2.075340
# 2012-03-09    1.965785
# 2012-03-10   -1.061167
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.162303
# 2012-03-07 00:00:00+00:00   -1.398904
# 2012-03-08 00:00:00+00:00   -2.075340
# 2012-03-09 00:00:00+00:00    1.965785
# 2012-03-10 00:00:00+00:00   -1.061167
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.162303
# 2012-03-06 19:00:00-05:00   -1.398904
# 2012-03-07 19:00:00-05:00   -2.075340
# 2012-03-08 19:00:00-05:00    1.965785
# 2012-03-09 19:00:00-05:00   -1.061167
# Freq: D, dtype: float64

# %%
rng = pd.date_range("1/1/2012", periods=5, freq="M")
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)),index =rng)

# %%
ts
# Out:
# 2012-01-31    0.182456
# 2012-02-29    0.514430
# 2012-03-31    0.526852
# 2012-04-30    0.067647
# 2012-05-31    0.473218
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01    0.182456
# 2012-02    0.514430
# 2012-03    0.526852
# 2012-04    0.067647
# 2012-05    0.473218
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.182456
# 2012-02-01    0.514430
# 2012-03-01    0.526852
# 2012-04-01    0.067647
# 2012-05-01    0.473218
# Freq: MS, dtype: float64

# %%
prng = pd.period_range("1990Q1","2000Q4",freq="Q-NOV")
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)
ts
# Out:
# 1990Q1    1.568148
# 1990Q2   -1.074314
# 1990Q3    1.182284
# 1990Q4   -0.303693
# 1991Q1    0.039930
# 1991Q2    0.657377
# 1991Q3   -0.744758
# 1991Q4    0.796817
# 1992Q1   -2.381870
# 1992Q2    0.554447
# 1992Q3    1.875873
# 1992Q4    0.841303
# 1993Q1   -0.062359
# 1993Q2    0.192798
# 1993Q3   -0.286406
# 1993Q4   -1.349518
# 1994Q1    0.253887
# 1994Q2    0.484707
# 1994Q3    2.006652
# 1994Q4   -1.354844
# 1995Q1    0.462084
# 1995Q2    0.664964
# 1995Q3   -0.231841
# 1995Q4    0.233994
# 1996Q1    0.439523
# 1996Q2   -1.485188
# 1996Q3    0.412205
# 1996Q4   -0.584880
# 1997Q1   -0.539284
# 1997Q2   -1.185400
# 1997Q3    0.104925
# 1997Q4   -1.951748
# 1998Q1   -0.050718
# 1998Q2    0.670465
# 1998Q3    0.201546
# 1998Q4   -0.646655
# 1999Q1    0.480401
# 1999Q2   -0.617400
# 1999Q3   -1.298639
# 1999Q4    0.176203
# 2000Q1   -1.797185
# 2000Q2    0.046028
# 2000Q3   -1.818932
# 2000Q4   -0.538597
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq("M","e")+1).asfreq("H","s")+9

# %%
ts.head()
# Out:
# 1990-03-01 09:00    1.568148
# 1990-06-01 09:00   -1.074314
# 1990-09-01 09:00    1.182284
# 1990-12-01 09:00   -0.303693
# 1991-03-01 09:00    0.039930
# Freq: H, dtype: float64

# %% [markdown]
# # Plotting

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=["A","B","C","D"])

# %%
df = df.cumsum()

# %%
plt.figure()
df.plot()
plt.legend(loc="best")

# %% [markdown]
# # Gotchas
